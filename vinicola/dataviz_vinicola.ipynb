# %% [markdown]
# # Visualização de Dados [Vinho e Derivados]
#
# Neste notebook a visualização de dados, a partir da criação de uma tabela contendo as seguintes informações:
# 1. País de origem (Brasil).
# 2. País de destino.
# 3. Quantidade em litros de vinho exportado (utilize: 1KG =1L)
# 4. Valor em US$.
#
# O objetivo é visualizar:
# - O montante de venda de exportação nos últimos 15 anos, separando a análise por país e trazendo quais as prospecções futuras e possíveis ações para uma melhoria nas exportações.
# - Gráficos atraentes e que passem a ideia central de projeção do futuro.

# %%
pip install matplotlib
# Out:
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from exploratory_visualization import read_csv, select_cols

# %%
df = read_csv()
df = select_cols(df)

# %%
df.rename(columns={'País': 'país_destino'}, inplace=True)

# %%
df[df.columns[-1]]
# Out:
# 0          46
# 1           0
# 2        6741
# 3           0
# 4           0
#         ...
# 119         0
# 120    149842
# 121         0
# 122     35944
# 123         0
# Name: 2021.1, Length: 124, dtype: int64

# %% [markdown]
# # Transformando dados em Gráficos

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
# df_plot = df.set_index("país_destino")

# %%
# df_plot.columns
# Out:
# Index(['2006', '2006.1', '2007', '2007.1', '2008', '2008.1', '2009', '2009.1',
#        '2010', '2010.1', '2011', '2011.1', '2012', '2012.1', '2013', '2013.1',
#        '2014', '2014.1', '2015', '2015.1', '2016', '2016.1', '2017', '2017.1',
#        '2018', '2018.1', '2019', '2019.1', '2020', '2020.1', '2021', '2021.1'],
#       dtype='object')

# %%
# df_plot
# Out:
#                                   2006  2006.1    2007  2007.1    2008  \
# país_destino
# Afeganistão                          0       0       0       0       0
# África do Sul                        0       0       0       0       0
# Alemanha, República Democrática  38302   89231  119512  238052  265742
# Angola                            3766   18293   25931   49753   25721
# Anguilla                             0       0       0       0       0
# ...                                ...     ...     ...     ...     ...
# Tuvalu                               0       0       0       0       0
# Uruguai                           1008    1685       0       0       0
# Vanuatu                              0       0       0       0       0
# Venezuela                            0       0   20700   27370       0
# Vietnã                            2013    2362       0       0       0
#
#                                  2008.1    2009  2009.1   2010  2010.1  ...  \
# ...

# %%
df.plot(x="país_destino", kind="barh", figsize=(20,35))
plt.title("Exportação de vinhos")
# Out:
# Text(0.5, 1.0, 'Exportação de vinhos')
